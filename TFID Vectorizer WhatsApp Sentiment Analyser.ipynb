# %%
import pandas as pd

# %%
df = pd.read_csv("mabel.txt",header=None,on_bad_lines="skip",encoding='utf8')
df
# Out:
#            0                                                  1
# 0   05/12/19   1:42 pm - Messages to this chat and calls are...
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# ...

# %%
df=df.drop(0)
df
# Out:
#            0                                                  1
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# 14  05/12/19                      1:48 pm - Mabel Infoziant: ok
# ...

# %%
df.columns=['Date','Chat']
df
# Out:
#         Date                                               Chat
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# 14  05/12/19                      1:48 pm - Mabel Infoziant: ok
# ...

# %%
Message=df["Chat"].str.split("-",n=1,expand=True)
Message
# Out:
#              0                                                  1
# 1     1:42 pm     Mabel Infoziant: Hi this is Mabel we just spoke
# 2     1:42 pm              Mabel Infoziant: What’s your full name
# 3     1:42 pm                                 AR❤: Ramisha Rani K
# 4     1:42 pm                                 Mabel Infoziant: Ok
# 5     1:42 pm             Mabel Infoziant: ramisharanik@gmail.com
# 6     1:43 pm                     Mabel Infoziant: Your email Id?
# 7     1:43 pm                                        AR❤: Yes Mam
# 8     1:43 pm    Mabel Infoziant: I will send 2 abstracts for ...
# 9     1:43 pm                                       AR❤: Yeah mam
# 10    1:43 pm    Mabel Infoziant: Give me the list that u have...
# 11    1:43 pm    Mabel Infoziant: Send me cbe office address a...
# 12    1:44 pm    AR❤: Yeah Mam within Evening I will forward y...
# 13    1:45 pm    AR❤: Tomorrow I have to visit the office.yet ...
# ...

# %%
df["Time"]=Message[0]
df
# Out:
#         Date                                               Chat        Time
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...    1:42 pm
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name    1:42 pm
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K    1:42 pm
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok    1:42 pm
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...    1:42 pm
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?    1:43 pm
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam    1:43 pm
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...    1:43 pm
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam    1:43 pm
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...    1:43 pm
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...    1:43 pm
# ...

# %%
Message1=Message[1].str.split(":",n=1,expand=True)
Message1
# Out:
#                    0                                                  1
# 1    Mabel Infoziant                     Hi this is Mabel we just spoke
# 2    Mabel Infoziant                              What’s your full name
# 3                AR❤                                     Ramisha Rani K
# 4    Mabel Infoziant                                                 Ok
# 5    Mabel Infoziant                             ramisharanik@gmail.com
# 6    Mabel Infoziant                                     Your email Id?
# 7                AR❤                                            Yes Mam
# 8    Mabel Infoziant     I will send 2 abstracts for u to start working
# 9                AR❤                                           Yeah mam
# 10   Mabel Infoziant                   Give me the list that u have too
# 11   Mabel Infoziant   Send me cbe office address and phone number I...
# 12               AR❤    Yeah Mam within Evening I will forward you mam.
# ...

# %%
df["Name"]=Message1[0]
df["Chat"]=Message1[1]
df
# Out:
#         Date                                               Chat        Time  \
# 1   05/12/19                     Hi this is Mabel we just spoke    1:42 pm
# 2   05/12/19                              What’s your full name    1:42 pm
# 3   05/12/19                                     Ramisha Rani K    1:42 pm
# 4   05/12/19                                                 Ok    1:42 pm
# 5   05/12/19                             ramisharanik@gmail.com    1:42 pm
# 6   05/12/19                                     Your email Id?    1:43 pm
# 7   05/12/19                                            Yes Mam    1:43 pm
# 8   05/12/19     I will send 2 abstracts for u to start working    1:43 pm
# 9   05/12/19                                           Yeah mam    1:43 pm
# 10  05/12/19                   Give me the list that u have too    1:43 pm
# 11  05/12/19   Send me cbe office address and phone number I...    1:43 pm
# ...

# %%
df=df[["Date","Time","Name","Chat"]]
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 1 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50 non-null     object
#  1   Time    50 non-null     object
#  2   Name    50 non-null     object
#  3   Chat    50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset.dropna(inplace=True)

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()

# %%
senti=sid.polarity_scores(dataset['Chat'][4])

# %%
senti
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}

# %%
 def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')

# %%
data_Senti
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
pos
# Out:
#             count
# comp_score
# pos            48
# neg             2

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=tfidf.fit_transform(df["Chat"])

# %%
from sklearn.decomposition import NMF
nmf_model=NMF(n_components=5,random_state=42)
nmf_model.fit(dtm)
# Out:
# NMF(n_components=5, random_state=42)

# %%
for index,topic in enumerate(nmf_model.components_):
    results=([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['share', 'soon', 'ask', 'yes', 'sure', 'read', 'abstract', 'kk', 'yeah', 'mam']
# ['hi', 'kk', 'know', 'meeting', 'yes', 'just', 'send', 'tomorrow', 'mam', 'ok']
# ['details', 'abstracts', 'start', 'students', 'phone', 'ask', 'office', 'number', 'vignesh', 'send']
# ['ask', 'abstracts', 'number', 'mam', 'office', 'know', 'just', 'tomorrow', 'church', 'hi']
# ['students', 'know', 'sure', 'share', 'soon', 'meeting', 'details', 'yes', 'need', 'ramisha']

# %%
topic_results=nmf_model.transform(dtm)
df["Topic"]=topic_results.argmax(axis=1)

# %%
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
df["Topic"].value_counts()
# Out:
# Topic
# 0    22
# 2    12
# 4     6
# 3     5
# 1     5
# Name: count, dtype: int64

# %%
#!pip install wordCloud

# %%
dataset=df
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
comment_words = []
stoplist = stopwords.words('english')
stoplist.extend(['omitted', 'voice','missed','call','video','deleted','media','message'])
wordcloudss="This function saves image"
dataset.index=range(dataset.shape[0])
for i in range(1,len(dataset)): 
    comment_words.append(dataset['Chat'][i])
    vv=" ".join(comment_words)          
    wordcloud = WordCloud(width = 800, height = 800, 
                                background_color ='white', 
                                      stopwords = stoplist, 
                                      min_font_size = 10).generate(vv)         
plt.figure(figsize = (9, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('wordcloud.PNG')
plt.show() 
print("Successfully created")
wordcloudss="This function saves image"
# Out:
# Successfully created

# %%
label_counts = df['Name'].value_counts()

print("Media Count sent by each person:")
print(label_counts)
# Out:
# Media Count sent by each person:
# Name
#  AR❤                27
#  Mabel Infoziant    23
# Name: count, dtype: int64

# %%
# Convert 'Date' column to datetime format
df['Date1'] = pd.to_datetime(df['Date'],format='%d/%m/%y')
#print(df['Date'])

# Extract most active date
most_active_date = df['Date1'].value_counts().idxmax()
most_active_date_str = most_active_date.strftime('%Y-%m-%d')

# Extract most active day
most_active_day = most_active_date.strftime('%A')

# Extract most active time
most_active_time = df['Time'].value_counts().idxmax()


print("Most active date:", most_active_date_str)
print("Most active day:", most_active_day)
print("Most active time:", most_active_time)
# Out:
# Most active date: 2019-12-05
# Most active day: Thursday
# Most active time:  1:43 pm

# %%
df['num_words'] = df['Chat'].apply(lambda x: len(nltk.word_tokenize(x)))

# Calculate average number of words per message for each name
average_words_per_message = df.groupby('Name')['num_words'].mean()

# Determine the threshold for talkative vs less talkative
median_num_words = average_words_per_message.median()

# Classify each name as Talkative or Less talkative
def classify_talkativeness(avg_words):
    if avg_words >= median_num_words:
        return 'Talkative'
    else:
        return 'Less talkative'

df['talkativeness'] = df['Name'].map(average_words_per_message.apply(classify_talkativeness))

# Drop duplicates to ensure each name appears only once in the result
unique_names = df.drop_duplicates(subset='Name')

# Iterate over the unique names and print the result
for index, row in unique_names.iterrows():
    print(f"{row['talkativeness']}: {row['Name']}")
# Out:
# Talkative:  Mabel Infoziant
# Less talkative:  AR❤

# %%
import pandas as pd
import re

# Define regular expressions for different types of content
media_regex = r'\[image\]|\[video\]'
deleted_message_regex = r'Did you see my deleted message\?'
missed_voice_call_regex = r'Missed voice call from (\w+)\.'
missed_video_call_regex = r'Missed video call from (\w+)\.'


# Count occurrences of each type of content
total_media_count = df['Chat'].str.count(media_regex).sum()
deleted_message_count = df['Chat'].str.count(deleted_message_regex).sum()
missed_voice_call_count = len(re.findall(missed_voice_call_regex, ' '.join(df['Chat'])))
missed_video_call_count = len(re.findall(missed_video_call_regex, ' '.join(df['Chat'])))

print("Total media count:", total_media_count)
print("Deleted message count:", deleted_message_count)
print("Missed voice call count:", missed_voice_call_count)
print("Missed video call count:", missed_video_call_count)
# Out:
# Total media count: 0
# Deleted message count: 0
# Missed voice call count: 0
# Missed video call count: 0

# %%
import pandas as pd


# Define keywords indicative of flirtatious behavior
flirt_keywords = ['beautiful', 'sweet', 'thinking about you', 'dinner', 'date','cute','love','hot','sexy','hug']

# Function to calculate flirt percentage for each name
def calculate_flirt_percentage(name):
    # Filter chat messages for the specific name
    name_messages = df[df['Name'] == name]['Chat']
    total_messages = len(name_messages)
    
    # Count flirtatious messages
    flirt_messages = name_messages.apply(lambda x: any(keyword in x.lower() for keyword in flirt_keywords)).sum()
    
    # Calculate flirt percentage
    flirt_percentage = (flirt_messages / total_messages) * 100 if total_messages > 0 else 0
    return flirt_percentage

# Calculate flirt percentage for each unique name
unique_names = df['Name'].unique()
flirt_percentages = {name: calculate_flirt_percentage(name) for name in unique_names}

print("Flirt percentages:")
for name, flirt_percentage in flirt_percentages.items():
    print(f"{name}: {flirt_percentage:.2f}%")
# Out:
# Flirt percentages:
#  Mabel Infoziant: 4.35%
#  AR❤: 3.70%

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Calculate the total number of messages and the number of days
total_messages = df['Chat'].count()
#print(total_messages)
total_days = df['Date'].nunique()
#print(total_days)

# Calculate the average number of messages per day
average_messages_per_day = (total_messages / total_days).round()

print("Average number of messages per day:", average_messages_per_day)
# Out:
# Average number of messages per day: 7.0
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6112\948709350.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'] = pd.to_datetime(df['Date'])
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(dataset.groupby('Date').size().reset_index(name='Message Count'), x='Date', y='Message Count')
plt.title('Message Count per Date')
plt.xlabel('Date')
plt.ylabel('Message Count')
plt.xticks(rotation=45)
plt.show()
